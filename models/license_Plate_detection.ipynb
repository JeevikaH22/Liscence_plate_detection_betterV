# %%
from ultralytics import YOLO
import cv2
import torch

# %%
model = YOLO("yolo26n.pt")

# %%
model.train(
    data=r"E:\engg\Data\licencePlate_detection\data.yaml",
    epochs=15,
    imgsz=640
)
# Out:
# Ultralytics 8.4.46  Python-3.13.5 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %%
import cv2

# %%
img = cv2.imread(r"E:\engg\Data\licencePlate_detection\images\train\8a5e800c98b16750.jpg")

results = model(img)

for r in results:
    boxes = r.boxes
    for box in boxes:
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        conf = float(box.conf[0])
        cls = int(box.cls[0])

        cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(img, f"{cls} {conf:.2f}", (x1, y1 - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

cv2.imshow("License Plate Detection", img) 
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 0: 448x640 1 license_plate, 55.6ms
# Speed: 4.1ms preprocess, 55.6ms inference, 8.9ms postprocess per image at shape (1, 3, 448, 640)

# %%
torch.save(model.state_dict(), "lisence_plate_detection.pt")
